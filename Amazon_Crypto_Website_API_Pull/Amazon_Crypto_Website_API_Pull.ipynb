# %% [markdown]
# # AMAZON CRYPTO WEBSITE API PULL PROJECT

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'e545ee61-b9a6-445b-84c6-2a4d409670a3',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-11-14T12:18:07.460Z', 'error_code': 0, 'error_message': None, 'elapsed': 23, 'credit_count': 1, 'notice': None, 'total_count': 8830}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10552, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
pd.set_option('display.max_columns',None)

# %%
import pandas as pd
df=pd.json_normalize(data['data'])

# %%
df['timestamp']=pd.to_datetime('now')
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10552
# 1    1027     Ethereum    ETH      ethereum              7778
# 2     825  Tether USDt   USDT        tether             65676
# 3    1839          BNB    BNB           bnb              1759
# 4      52          XRP    XRP           xrp              1141
# 5    3408         USDC   USDC      usd-coin             14922
# 6    5426       Solana    SOL        solana               546
# 7    2010      Cardano    ADA       cardano               972
# 8      74     Dogecoin   DOGE      dogecoin               825
# 9    1958         TRON    TRX          tron               868
# 10   3890      Polygon  MATIC       polygon              1066
# 11  11419      Toncoin    TON       toncoin               171
# 12   1975    Chainlink   LINK     chainlink              1430
# 13   6636     Polkadot    DOT  polkadot-new               612
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': 'e545ee61-b9a6-445b-84c6-2a4d409670a3',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    df2=pd.json_normalize(data['data'])
    df2['timestamp']=pd.to_datetime('now')
    df
    df_append = pd.DataFrame(df2)
    df = pd.concat([df2,df_append])
#     if not os.path.isfile(r'C:\Users\anshv\Desktop\Data Analyst Projects\Amazon_Crypto_Website_API_Pull\API.csv'):
#         df.to_csv(r'C:\Users\anshv\Desktop\Data Analyst Projects\Amazon_Crypto_Website_API_Pull\API.csv',header='column_names')
#     else:
#         df.to_csv(r'C:\Users\anshv\Desktop\Data Analyst Projects\Amazon_Crypto_Website_API_Pull\API.csv',mode='a',header=False)

# %%
import os
from time import time
from time import sleep
for i in range(333):
    api_runner()
    print('API runner completed successfully')
    sleep(60)
exit()
# Out:
# {'status': {'timestamp': '2023-11-14T12:34:33.390Z', 'error_code': 0, 'error_message': None, 'elapsed': 18, 'credit_count': 1, 'notice': None, 'total_count': 8832}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10552, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
df72=pd.read_csv(r'C:\Users\anshv\Desktop\Data Analyst Projects\Amazon_Crypto_Website_API_Pull\API.csv')
df72
# Out:
#     Unnamed: 0     id         name symbol          slug  num_market_pairs  \
# 0            0      1      Bitcoin    BTC       bitcoin             10552
# 1            1   1027     Ethereum    ETH      ethereum              7778
# 2            2    825  Tether USDt   USDT        tether             65676
# 3            3   1839          BNB    BNB           bnb              1759
# 4            4     52          XRP    XRP           xrp              1141
# 5            5   3408         USDC   USDC      usd-coin             14922
# 6            6   5426       Solana    SOL        solana               546
# 7            7   2010      Cardano    ADA       cardano               972
# 8            8     74     Dogecoin   DOGE      dogecoin               825
# 9            9   1958         TRON    TRX          tron               869
# 10          10   3890      Polygon  MATIC       polygon              1066
# 11          11  11419      Toncoin    TON       toncoin               171
# ...

# %%
pd.set_option('display.max_rows', None)
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10552
# 1    1027     Ethereum    ETH      ethereum              7778
# 2     825  Tether USDt   USDT        tether             65676
# 3    1839          BNB    BNB           bnb              1759
# 4      52          XRP    XRP           xrp              1141
# 5    3408         USDC   USDC      usd-coin             14922
# 6    5426       Solana    SOL        solana               546
# 7    2010      Cardano    ADA       cardano               972
# 8      74     Dogecoin   DOGE      dogecoin               825
# 9    1958         TRON    TRX          tron               868
# 10   3890      Polygon  MATIC       polygon              1066
# 11  11419      Toncoin    TON       toncoin               171
# 12   1975    Chainlink   LINK     chainlink              1430
# 13   6636     Polkadot    DOT  polkadot-new               612
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)
df
# Out:
#        id             name symbol             slug  num_market_pairs  \
# 0       1          Bitcoin    BTC          bitcoin             10552
# 1    1027         Ethereum    ETH         ethereum              7778
# 2     825      Tether USDt   USDT           tether             65676
# 3    1839              BNB    BNB              bnb              1759
# 4      52              XRP    XRP              xrp              1141
# 5    3408             USDC   USDC         usd-coin             14922
# 6    5426           Solana    SOL           solana               546
# 7    2010          Cardano    ADA          cardano               972
# 8      74         Dogecoin   DOGE         dogecoin               825
# 9    1958             TRON    TRX             tron               869
# 10   3890          Polygon  MATIC          polygon              1066
# 11  11419          Toncoin    TON          toncoin               171
# 12   1975        Chainlink   LINK        chainlink              1430
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#                  quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                             -0.17794                      -1.43394
# Ethereum                            -0.38097                      -0.96588
# Tether USDt                          0.03161                      -0.00033
# BNB                                 -0.42314                      -0.42496
# XRP                                  0.08979                       0.12011
# USDC                                 0.01665                       0.02247
# Solana                              -0.23055                      -8.34895
# Cardano                              0.11870                      -2.54043
# Dogecoin                            -0.00246                      -4.82721
# TRON                                -0.26988                      -3.99177
# Polygon                              2.67090                       8.63785
# ...

# %%
df4=df3.stack()
df4
# Out:
# name
# Bitcoin          quote.USD.percent_change_1h    -0.17794
#                  quote.USD.percent_change_24h   -1.43394
#                  quote.USD.percent_change_7d     4.54456
#                  quote.USD.percent_change_30d   35.12878
#                  quote.USD.percent_change_60d   37.30341
#                                                   ...
# Wrapped Bitcoin  quote.USD.percent_change_24h   -1.52386
#                  quote.USD.percent_change_7d     4.54205
#                  quote.USD.percent_change_30d   34.98595
#                  quote.USD.percent_change_60d   37.02252
#                  quote.USD.percent_change_90d   24.57923
# Length: 90, dtype: float64

# %%
pd.set_option('display.max_rows', None)
df5 = df4.to_frame(name='values')
df5.count()
# Out:
# values    90
# dtype: int64

# %%
df5
# Out:
#                                                 values
# name
# Bitcoin         quote.USD.percent_change_1h   -0.17794
#                 quote.USD.percent_change_24h  -1.43394
#                 quote.USD.percent_change_7d    4.54456
#                 quote.USD.percent_change_30d  35.12878
#                 quote.USD.percent_change_60d  37.30341
#                 quote.USD.percent_change_90d  24.70456
# Ethereum        quote.USD.percent_change_1h   -0.38097
#                 quote.USD.percent_change_24h  -0.96588
#                 quote.USD.percent_change_7d    8.11742
#                 quote.USD.percent_change_30d  30.55951
#                 quote.USD.percent_change_60d  25.19573
#                 quote.USD.percent_change_90d  11.48178
# Tether USDt     quote.USD.percent_change_1h    0.03161
#                 quote.USD.percent_change_24h  -0.00033
#                 quote.USD.percent_change_7d    0.00621
#                 quote.USD.percent_change_30d   0.04948
# ...

# %%
index = pd.Index(range(90))
df6 = df5.reset_index()
df6
# Out:
#                name                       level_1    values
# 0           Bitcoin   quote.USD.percent_change_1h  -0.17794
# 1           Bitcoin  quote.USD.percent_change_24h  -1.43394
# 2           Bitcoin   quote.USD.percent_change_7d   4.54456
# 3           Bitcoin  quote.USD.percent_change_30d  35.12878
# 4           Bitcoin  quote.USD.percent_change_60d  37.30341
# 5           Bitcoin  quote.USD.percent_change_90d  24.70456
# 6          Ethereum   quote.USD.percent_change_1h  -0.38097
# 7          Ethereum  quote.USD.percent_change_24h  -0.96588
# 8          Ethereum   quote.USD.percent_change_7d   8.11742
# 9          Ethereum  quote.USD.percent_change_30d  30.55951
# 10         Ethereum  quote.USD.percent_change_60d  25.19573
# 11         Ethereum  quote.USD.percent_change_90d  11.48178
# 12      Tether USDt   quote.USD.percent_change_1h   0.03161
# 13      Tether USDt  quote.USD.percent_change_24h  -0.00033
# 14      Tether USDt   quote.USD.percent_change_7d   0.00621
# ...

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#                name                percent_change    values
# 0           Bitcoin   quote.USD.percent_change_1h  -0.17794
# 1           Bitcoin  quote.USD.percent_change_24h  -1.43394
# 2           Bitcoin   quote.USD.percent_change_7d   4.54456
# 3           Bitcoin  quote.USD.percent_change_30d  35.12878
# 4           Bitcoin  quote.USD.percent_change_60d  37.30341
# 5           Bitcoin  quote.USD.percent_change_90d  24.70456
# 6          Ethereum   quote.USD.percent_change_1h  -0.38097
# 7          Ethereum  quote.USD.percent_change_24h  -0.96588
# 8          Ethereum   quote.USD.percent_change_7d   8.11742
# 9          Ethereum  quote.USD.percent_change_30d  30.55951
# 10         Ethereum  quote.USD.percent_change_60d  25.19573
# 11         Ethereum  quote.USD.percent_change_90d  11.48178
# 12      Tether USDt   quote.USD.percent_change_1h   0.03161
# 13      Tether USDt  quote.USD.percent_change_24h  -0.00033
# 14      Tether USDt   quote.USD.percent_change_7d   0.00621
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace([	'quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#                name percent_change    values
# 0           Bitcoin             1h  -0.17794
# 1           Bitcoin            24h  -1.43394
# 2           Bitcoin             7d   4.54456
# 3           Bitcoin            30d  35.12878
# 4           Bitcoin            60d  37.30341
# 5           Bitcoin            90d  24.70456
# 6          Ethereum             1h  -0.38097
# 7          Ethereum            24h  -0.96588
# 8          Ethereum             7d   8.11742
# 9          Ethereum            30d  30.55951
# 10         Ethereum            60d  25.19573
# 11         Ethereum            90d  11.48178
# 12      Tether USDt             1h   0.03161
# 13      Tether USDt            24h  -0.00033
# 14      Tether USDt             7d   0.00621
# 15      Tether USDt            30d   0.04948
# 16      Tether USDt            60d   0.03257
# 17      Tether USDt            90d   0.17142
# 18              BNB             1h  -0.42314
# 19              BNB            24h  -0.42496
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')
# Out:
# C:\Users\anshv\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      36272.96378 2023-11-14 18:05:40.611800
# 0  Bitcoin      36272.96378 2023-11-14 18:05:40.611800

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
